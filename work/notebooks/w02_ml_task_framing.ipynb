# %% [markdown]
# <a href="https://colab.research.google.com/github/yumna-09/FlyRank-ML-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yumna-09/FlyRank-ML-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Task type: Clustering
# My lane is "Structured Content Archetype Clustering" there's no predefined yes/no label or ranking order here. We're simply grouping content pages into naturally similar clusters based on their performance behavior (impressions, CTR, position, engagement, age). It's not ranking because we don't need "which one comes first," we need groups. It's not classification because there's no observed outcome label to predict. It's not scoring either, because each page doesn't need a single number it needs group membership.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Nothing is directly predicted here, since clustering doesn't work with a target label. There's no predefined label in our dataset telling us which group a page belongs to instead, clustering figures this out for us; it looks at the data and decides which pages naturally belong together.
# Input signals: impressions_90d, ctr, avg_position, along with related behavior columns like engagement_rate and content_age_days.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Success metric: I'm going with silhouette score since it directly tells me if my clusters are actually separated or just mushed together. It goes from -1 to +1 closer to +1 is good (tight, distinct clusters), near 0 means my groups are basically overlapping, and negative means something's wrong. Honestly I'm not chasing a perfect score here for a decision-support tool like this, anything reasonably above 0 combined with clusters that make sense is enough. So alongside the number, I'll manually check: does my "champions" cluster actually look like champions (high impressions, good position, high CTR), or did the algorithm just group random noise together?

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# Unit of analysis: So each row here is basically one content page identified by content_id with a snapshot of how it performed over the last 90 days (impressions, clicks, CTR, position, engagement) plus some basic info about the page itself (content type, age, word count). Nothing time-series here, just one page = one row = one full performance summary.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# If I wrote a simple if-else rule, it would only look at one thing at a time like "if impressions > 10,000, call it a champion." But real pages don't behave on just one dimension. A page could have high impressions but a terrible CTR, or low impressions but strong engagement. Writing manual rules that account for every combination of 5+ signals (impressions, CTR, position, engagement, age) would mean writing dozens of nested if-else conditions, and I'd probably still miss patterns. Clustering looks at all these signals together and finds the groupings on its own, without me having to guess the right combination of thresholds.
# For instance, a page could have high impressions AND high CTR (a real champion), or high impressions but low CTR (visible but underperforming) an if-else rule based only on impressions would lump both into the same "champion" bucket, which is misleading.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
